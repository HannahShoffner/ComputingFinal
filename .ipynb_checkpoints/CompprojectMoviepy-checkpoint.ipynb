# %% [markdown]
# ### This imports the moviepy code and three specific functions.

# %%
from moviepy import VideoFileClip, TextClip, CompositeVideoClip, ImageSequenceClip,ImageClip
import numpy as np

# %% [markdown]
# This first code example shortens the video to only include the portion with the worms in the picture. Instead of the video being its full 51 seconds long, it will end after 13 seconds.¶

# %%
clip = (
    VideoFileClip("lethargicpostcaf.mp4") 
    .subclipped(0, 13))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 clip = (
# ----> 2     VideoFileClip("lethargicpostcaf.mp4")
#       3     .subclipped(0, 13))
#
# NameError: name 'VideoFileClip' is not defined

# %% [markdown]
# This code creates a new video file from the preceding code.

# %%
clip.write_videofile("result.mp4")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 clip.write_videofile("result.mp4")
#
# NameError: name 'clip' is not defined

# %% [markdown]
# ### Process is repeated for videos of each of the swim wells from data recorded on March 21. Note that minutes and seconds can be listed as strings for easier clipping.

# %%
clip = (
    VideoFileClip("zall.mp4") 
    .subclipped(8,38))
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '0', 'compatible_brands': 'mp41isom', 'creation_time': '2025-03-21T16:58:18.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1920, 1080], 'bitrate': 5857, 'fps': 9.71, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'creation_time': '2025-03-21T16:58:18.000000Z', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]', 'encoder': 'AVC Coding'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 175, 'metadata': {'Metadata': '', 'creation_time': '2025-03-21T16:58:18.000000Z', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 61.6, 'bitrate': 6038, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264
# ...

# %% [markdown]
# The following code uploads an image of a red circle and defines it as a "logo," as well as defining the space the circle will be placed.

# %%
logo_clip = ImageClip("redcircle.png").resized(width=200)
logo_clip = logo_clip.with_position((600, 375))
maskclip2 = ImageClip("red.jpg", is_mask=True)

# %%
logo_clip = logo_clip.with_duration(25).with_start(1)

# %%
final_clip = CompositeVideoClip([clip, logo_clip])

# %%
final_clip.write_videofile("zzzznewzs.mp4")
# Out:
#
#
#
#
#
#
# ...
# me_index:   8%|████▌                                                   | 24/291 [3:13:48<01:04,  4.12it/s, now=None]
#
# index:   1%|▍                                                          | 2/291 [10:46<01:38,  2.92it/s, now=None]
#
#
#
#
#
#
#
#
# ...
# me_index:   8%|████▌                                                   | 24/291 [3:13:48<01:04,  4.12it/s, now=None]
#
# index:   1%|▍                                                          | 2/291 [10:46<01:38,  2.92it/s, now=None]
#
#
# ex:   1%|▍                                                          | 2/291 [03:23<01:27,  3.31it/s, now=None]
# MoviePy - Building video zzzznewzs.mp4.
# MoviePy - Writing audio in zzzznewzsTEMP_MPY_wvf_snd.mp3
#                                                                          | 0/662 [00:00<?, ?it/s, now=None]
#
#
#
# ▏                                                                | 2/662 [00:00<01:24,  7.80it/s, now=None]
#
#
#
# ...
